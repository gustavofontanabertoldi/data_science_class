# %%
produto = "Computador"
quantidade = 10
preco_refrigerante = 5.50

print(produto)
print(quantidade)
print(preco_refrigerante)

aux = quantidade
quantidade = preco_refrigerante
preco_refrigerante = aux

print(quantidade)
print(preco_refrigerante)

dia = "01"
mes = "11"
ano = "2005"

print(f"{dia}/{mes}/{ano}")

# %%
a = "100"
print(type(a))

var_1 = "opa"
var_2 = True
var_3 = 5.50
var_4 = 67

print(type(var_1))
print(type(var_2))
print(type(var_3))
print(type(var_4))

temperatura = float(36.50)
print(temperatura)

# 4. Bool

comprimento = 12
print(type(comprimento))
novo_comprimento = 12.0
print(type(novo_comprimento))

# %%
cidade = "Jaraguá do Sul"
print(f"Você mora em {cidade}")

texto_1 = "hello"
texto_2 = "world"

print(f"{texto_1}{texto_2}")

cor = input("Digite sua cor favorita: ")
print(f"Sua cor favorita é {cor}")

nome = input("digite seu primeiro nome: ")
sobrenome = input("digite seu sobrenome: ")

print(f"Seu nome é {nome} {sobrenome}")

print("====Arriverderci====")

# %%
a = 10
print(a*2)

altura = float(1.90)
print(altura)

num_a = int(10)
num_b = int(57)
print(num_a + num_b)

num_c = str(10)
print(type(num_c))

# 5. Erro de tipagem
